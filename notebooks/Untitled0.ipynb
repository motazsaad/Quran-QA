# %%
# !wget https://kkb-production.jupyter-proxy.kaggle.net/k/91001990/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2IiwidHlwIjoiSldUIn0..KvyyDb7MMEPnVTcZSrkEDQ.tizHdwvn4ETKf0hZBfqveydgNFQHwUVmWJNWq6i_M-28MjS72ytuEFd5Q0yrw_14QsG7-XJ6LHDrso84NWbAzLi7GwR_rwZI5qRlal1Dodaj3dNIu64LDW2_KzQt5Byo-OtaK4TtYmoMX8qq3h6jm-57mpw0BysQjaZENATGrTjvFpGhkPv7WcYwlTOJwsFoGw1fdRKUwGtu8o6NycQrow.Mg9cMp3pjw7zSFCy6a2E5Q/proxy/files/salti.zip
# Out:
# --2022-03-23 05:34:28--  https://kkb-production.jupyter-proxy.kaggle.net/k/91001990/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2IiwidHlwIjoiSldUIn0..KvyyDb7MMEPnVTcZSrkEDQ.tizHdwvn4ETKf0hZBfqveydgNFQHwUVmWJNWq6i_M-28MjS72ytuEFd5Q0yrw_14QsG7-XJ6LHDrso84NWbAzLi7GwR_rwZI5qRlal1Dodaj3dNIu64LDW2_KzQt5Byo-OtaK4TtYmoMX8qq3h6jm-57mpw0BysQjaZENATGrTjvFpGhkPv7WcYwlTOJwsFoGw1fdRKUwGtu8o6NycQrow.Mg9cMp3pjw7zSFCy6a2E5Q/proxy/files/salti.zip
# Resolving kkb-production.jupyter-proxy.kaggle.net (kkb-production.jupyter-proxy.kaggle.net)... 35.244.180.134
# Connecting to kkb-production.jupyter-proxy.kaggle.net (kkb-production.jupyter-proxy.kaggle.net)|35.244.180.134|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 499602723 (476M) [application/zip]
# Saving to: ‘salti.zip’
#
# salti.zip           100%[===================>] 476.46M  30.2MB/s    in 17s
#
# 2022-03-23 05:34:46 (28.4 MB/s) - ‘salti.zip’ saved [499602723/499602723]

# %%
# !unzip /content/salti.zip -d /content/drive/MyDrive/salti
# Out:
# Archive:  /content/salti.zip
#   inflating: /content/drive/MyDrive/salti/config.json
#   inflating: /content/drive/MyDrive/salti/pytorch_model.bin
#   inflating: /content/drive/MyDrive/salti/special_tokens_map.json
#   inflating: /content/drive/MyDrive/salti/tokenizer.json
#   inflating: /content/drive/MyDrive/salti/tokenizer_config.json
#   inflating: /content/drive/MyDrive/salti/vocab.txt

# %%
# !cp /content/drive/MyDrive/wissamantoun/Epoch-and-results.gdoc /content/drive/MyDrive/salti
# Out:
# cp: cannot open '/content/drive/MyDrive/wissamantoun/Epoch-and-results.gdoc' for reading: Operation not supported
